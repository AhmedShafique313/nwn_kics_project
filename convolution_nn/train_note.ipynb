# %%
import glob
import os
from PIL import Image
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.utils import to_categorical
import numpy as np
from sklearn.utils import shuffle

# %%
def get_image_data(image_path):
    im = img_to_array(load_img(image_path).resize((256, 256), Image.LANCZOS))
    im = im / 255.0
    return im

def data(path, label):
    X = []
    Y = []
    image_paths = []
    files = glob.glob(path + '/*.png')
    for file in files:
        image = get_image_data(file)
        X.append(image)
        Y.append(label)
        image_paths.append(file)
    return X, Y, image_paths

# %%
img_width, img_height = 256, 256

# Data directories:
train_data_dir_gun = r'C:\Users\Personal\Documents\projects\KICS Second Project\convolution_nn\dataset'
validation_data_dir_gun = r'C:\Users\Personal\Documents\projects\KICS Second Project\convolution_nn\valid'

# Hyperparameters:
epochs = 100
batch_size = 32

# %%
train_x1, train_y1, path_train1 = data(train_data_dir_gun, 1)
train_x = train_x1
train_y = train_y1
train_x, train_y = shuffle(train_x, train_y)
train_x = np.array(train_x)
train_y = np.array(train_y)
train_y = to_categorical(train_y, 2)

# %%
val_x1, val_y1, path_val_1 = data(validation_data_dir_gun, 1)
val_x = val_x1
val_y = val_y1
val_x, val_y = shuffle(val_x, val_y)
val_x = np.array(val_x)
val_y = np.array(val_y)
val_y = to_categorical(val_y, 2)

# %%
model = Sequential()
model.add(Conv2D(24, (3, 3), input_shape=(256, 256, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(2))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model:
model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(val_x, val_y))

# Test prediction:
gunshot = []
true_gun = []
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 1.0000 - loss: 0.5457 - val_accuracy: 1.0000 - val_loss: 2.4319e-06
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step - accuracy: 1.0000 - loss: 2.8358e-04 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step - accuracy: 1.0000 - loss: 2.8951e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 868ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 871ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 900ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 843ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 843ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 843ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 846ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 831ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 843ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 847ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 836ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 858ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 858ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 868ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 859ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
for im in val_x1:
    im = np.array(im)
    im = np.reshape(im, newshape=(1, 256, 256, 3))
    prediction = model.predict(im)
    classes_x = np.argmax(prediction, axis=1)

    gunshot.append(classes_x)
    true_gun.append(1)
    print("True class", 1, " predicted class", classes_x)

final_arrays = [path_val_1, true_gun, gunshot]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# True class 1  predicted class [1]

# %%
with open(r'C:\Users\Personal\Documents\projects\KICS Second Project\convolution_nn\new_8.csv', "a") as f:
    for i in range(len(final_arrays[0])):
        f.write(f"{final_arrays[0][i]},{final_arrays[1][i]},{final_arrays[2][i][0]}\n")
