# %%
import glob
import os
from PIL import Image
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.utils import to_categorical
import numpy as np
from sklearn.utils import shuffle

# %%
def get_image_data(image_path):
    im = img_to_array(load_img(image_path).resize((256, 256), Image.LANCZOS))
    im = im / 255.0
    return im

def data(path, label):
    X = []
    Y = []
    image_paths = []
    files = glob.glob(path + '/*.png')
    for file in files:
        image = get_image_data(file)
        X.append(image)
        Y.append(label)
        image_paths.append(file)
    return X, Y, image_paths

# %%
img_width, img_height = 256, 256

# Data directories:
train_data_dir_gun = r'C:\Users\Personal\Documents\projects\KICS Second Project\convolution_nn\dataset'
validation_data_dir_gun = r'C:\Users\Personal\Documents\projects\KICS Second Project\convolution_nn\valid'

# Hyperparameters:
epochs = 100
batch_size = 128

# %%
train_x1, train_y1, path_train1 = data(train_data_dir_gun, 1)
train_x = train_x1
train_y = train_y1
train_x, train_y = shuffle(train_x, train_y)
train_x = np.array(train_x)
train_y = np.array(train_y)
train_y = to_categorical(train_y, 2)

# %%
val_x1, val_y1, path_val_1 = data(validation_data_dir_gun, 1)
val_x = val_x1
val_y = val_y1
val_x, val_y = shuffle(val_x, val_y)
val_x = np.array(val_x)
val_y = np.array(val_y)
val_y = to_categorical(val_y, 2)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(256, 256, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model:
model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(val_x, val_y))

# Save the model:
model.save(r'C:\\Users\Personal\\Documents\\projects\KICS Second Project\convolution_nn\new_melspecto.keras')

# Test prediction:
gunshot = []
true_gun = []
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 817ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 816ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 903ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 758ms/step - accuracy: 1.0000 - loss: 8.4440e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 871ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 1.0000 - loss: 3.0894e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
for im in val_x1:
    im = np.array(im)
    im = np.reshape(im, newshape=(1, 256, 256, 3))
    prediction = model.predict(im)
    classes_x = np.argmax(prediction, axis=1)

    gunshot.append(classes_x)
    true_gun.append(1)
    print("True class", 1, " predicted class", classes_x)

final_arrays = [path_val_1, true_gun, gunshot]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# True class 1  predicted class [1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# True class 1  predicted class [1]

# %%
with open(r'C:\Users\Personal\Documents\projects\KICS Second Project\convolution_nn\new_1.csv', "a") as f:
    for i in range(len(final_arrays[0])):
        f.write(f"{final_arrays[0][i]},{final_arrays[1][i]},{final_arrays[2][i][0]}\n")
